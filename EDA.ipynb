# %%
# %pip install "numpy<2" pandas matplotlib scikit-learn seaborn scipy tensorflow torch nltk spacy

# %%
df = pd.read_csv('C:\\Users\\junji\\OneDrive\\Desktop\\stock_data.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
# Basic Information
print(df.info())

# Statistical Summary
print(df.describe())

# Value Counts (if needed — usually more useful for categorical data, but for demonstration, we can apply it stock by stock)
for col in df.columns:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts().head())

# %%
sns.pairplot(df)
plt.suptitle('Pairplot of Stocks', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Stocks')
plt.show()

# %%
df.hist(bins=20, figsize=(15,10))
plt.suptitle('Histograms of Stocks', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.title('Boxplot of Stock Prices')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Stock_1'], y=df['Stock_2'])
plt.title('Stock_1 vs Stock_2 Scatterplot')
plt.xlabel('Stock_1')
plt.ylabel('Stock_2')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: better plot style
sns.set(style="whitegrid")

# %%
# Example
df = pd.read_csv('C:\\Users\\junji\\OneDrive\\Desktop\\stock_data.csv')  # <-- replace with your filename if needed
df.head()
# Out:
#    Unnamed: 0     Stock_1     Stock_2    Stock_3     Stock_4     Stock_5
# 0  2020-01-01  101.764052  100.160928  99.494642   99.909756  101.761266
# 1  2020-01-02  102.171269   99.969968  98.682973  100.640755  102.528643
# 2  2020-01-03  103.171258   99.575237  98.182139  100.574847  101.887811
# 3  2020-01-04  105.483215   99.308641  97.149381  100.925017  101.490049
# 4  2020-01-05  107.453175   98.188428  99.575396  101.594411  101.604283

# %%
# Show data info
print(df.info())

# Show basic statistics
print(df.describe())

# Value counts for each categorical feature
for col in df.select_dtypes(include=['object', 'category']).columns:
    print(f"\nValue Counts for {col}:")
    print(df[col].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  365 non-null    object
#  1   Stock_1     365 non-null    float64
#  2   Stock_2     365 non-null    float64
#  3   Stock_3     365 non-null    float64
#  4   Stock_4     365 non-null    float64
#  5   Stock_5     365 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.2+ KB
# None
#           Stock_1     Stock_2     Stock_3     Stock_4     Stock_5
# count  365.000000  365.000000  365.000000  365.000000  365.000000
# mean   107.772577   81.105216   94.519502  117.407560  106.866865
# std      7.398296   11.435212    6.519213    6.778527    3.760968
# min     91.474442   62.414219   81.111434   99.909756   99.833309
# 25%    101.603117   69.328263   89.788068  112.209912  103.927072
# 50%    107.421299   84.283525   94.495546  117.788079  106.411328
# ...

# %%
sns.pairplot(df, diag_kind='kde')
plt.suptitle('Pairplot of Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(12,8))
# Select only numeric columns
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df.hist(figsize=(15,10), bins=30, edgecolor='black')
plt.suptitle('Histograms of Numerical Features', y=1.02)
plt.show()

# %%
# Draw boxplots for numerical columns
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(6,4))
sns.scatterplot(x=num_cols[0], y=num_cols[1], data=df)
plt.title(f'Scatter Plot between {num_cols[0]} and {num_cols[1]}')
plt.show()

# %%
### Observations:
- Pairplot: Feature X and Y seem positively correlated.
- Heatmap: Feature Z is highly negatively correlated with Target.
- Histograms: Feature A is right-skewed.
- Boxplots: Outliers detected in Feature B and Feature C.
- Scatterplot: Nonlinear relationship observed between Feature1 and Feature2.

# %%
### Final Summary of Findings:
- Dataset contains [number] rows and [number] columns.
- No major missing values (or) Missing values found in [columns].
- Features [list] are strongly correlated.
- Outliers present in [list of columns].
- Key trends: [describe trends like positive correlation, cluster formation, skewness].
- Next steps: Outlier treatment, Feature selection, Model building.
